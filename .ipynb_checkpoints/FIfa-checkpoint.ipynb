# %%
library(tidyverse)
install.packages("gridExtra")
install.packages("ggimage")
install.packages("cowplot")
install.packages("ggtext")
install.packages("magrittr")
# Out:
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.2
# ✔ tibble  3.1.6     ✔ dplyr   1.0.8
# ✔ tidyr   0.8.3     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# also installing the dependency ‘magick’
#
# Warning message in install.packages("ggimage"):
# “installation of package ‘magick’ had non-zero exit status”Warning message in install.packages("ggimage"):
# “installation of package ‘ggimage’ had non-zero exit status”Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
install.packages("DT")
library(data.table)
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
#
# Attaching package: ‘data.table’
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
# The following object is masked from ‘package:purrr’:
#
#     transpose

# %%
# Importing Library
library(stringr)
library(grid)


 
install.packages("e1071")
library(mclust)
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Package 'mclust' version 5.4.9
# Type 'citation("mclust")' for citing this R package in publications.
#
# Attaching package: ‘mclust’
#
# The following object is masked from ‘package:purrr’:
#
#     map

# %%
install.packages("qgraph")
library(methods)
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library(tidyr)
library(dplyr)
library(plyr)

# %%
install.packages("dtplyr")
install.packages("modeest")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
install.packages("recommenderlab")
# Out:
# Warning message:
# “dependencies ‘arules’, ‘irlba’ are not available”also installing the dependencies ‘float’, ‘RcppProgress’, ‘registry’, ‘recosystem’
#
# Warning message in install.packages("recommenderlab"):
# “installation of package ‘recommenderlab’ had non-zero exit status”Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library(readr)

# %%
install.packages("sqldf")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library(rpart)

# %%
install.packages("radarchart")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
FullData <- read_csv("more/complete.csv")
complemento = read_csv("demo/CompleteDataset.csv")
# Out:
# Parsed with column specification:
# cols(
#   .default = col_logical(),
#   ID = col_double(),
#   name = col_character(),
#   full_name = col_character(),
#   club = col_character(),
#   club_logo = col_character(),
#   special = col_double(),
#   age = col_double(),
#   league = col_character(),
#   birth_date = col_date(format = ""),
#   height_cm = col_double(),
#   weight_kg = col_double(),
#   body_type = col_character(),
#   flag = col_character(),
#   nationality = col_character(),
#   photo = col_character(),
#   eur_value = col_double(),
#   eur_wage = col_double(),
#   eur_release_clause = col_double(),
#   overall = col_double(),
#   potential = col_double()
#   # ... with 73 more columns
# )
# See spec(...) for full column specifications.
# Warning message:
# “Missing column names filled in: 'X1' [1]”Parsed with column specification:
# cols(
#   .default = col_character(),
#   X1 = col_double(),
#   Age = col_double(),
#   Overall = col_double(),
#   Potential = col_double(),
#   Special = col_double(),
#   `GK positioning` = col_double(),
#   CAM = col_double(),
#   CB = col_double(),
#   CDM = col_double(),
#   CF = col_double(),
#   CM = col_double(),
#   ID = col_double(),
#   LAM = col_double(),
#   LB = col_double(),
#   LCB = col_double(),
#   LCM = col_double(),
#   LDM = col_double(),
#   LF = col_double(),
#   LM = col_double(),
#   LS = col_double()
#   # ... with 13 more columns
# )
# See spec(...) for full column specifications.
# Warning message:
# “26 parsing failures.
#  row            col               expected actual                       file
# 1696 GK positioning no trailing characters     -2 'demo/CompleteDataset.csv'
# 1785 GK positioning no trailing characters     +1 'demo/CompleteDataset.csv'
# 4563 GK positioning no trailing characters     -2 'demo/CompleteDataset.csv'
# 4834 GK positioning no trailing characters     +2 'demo/CompleteDataset.csv'
# 5920 GK positioning no trailing characters     +1 'demo/CompleteDataset.csv'
# .... .............. ...................... ...... ..........................
# See problems(...) for more details.
# ”

# %%
setDT(FullData)
setDT(complemento)
names(FullData)
# Out:
#   [1] "ID"                                 "name"
#   [3] "full_name"                          "club"
#   [5] "club_logo"                          "special"
#   [7] "age"                                "league"
#   [9] "birth_date"                         "height_cm"
#  [11] "weight_kg"                          "body_type"
#  [13] "real_face"                          "flag"
#  [15] "nationality"                        "photo"
#  [17] "eur_value"                          "eur_wage"
#  [19] "eur_release_clause"                 "overall"
#  [21] "potential"                          "pac"
#  [23] "sho"                                "pas"
#  [25] "dri"                                "def"
#  [27] "phy"                                "international_reputation"
#  [29] "skill_moves"                        "weak_foot"
#  [31] "work_rate_att"                      "work_rate_def"
#  [33] "preferred_foot"                     "crossing"
#  [35] "finishing"                          "heading_accuracy"
#  [37] "short_passing"                      "volleys"
#  [39] "dribbling"                          "curve"
#  [41] "free_kick_accuracy"                 "long_passing"
#  [43] "ball_control"                       "acceleration"
#  [45] "sprint_speed"                       "agility"
#  [47] "reactions"                          "balance"
#  [49] "shot_power"                         "jumping"
#  [51] "stamina"                            "strength"
#  [53] "long_shots"                         "aggression"
#  [55] "interceptions"                      "positioning"
#  [57] "vision"                             "penalties"
#  [59] "composure"                          "marking"
#  [61] "standing_tackle"                    "sliding_tackle"
#  [63] "gk_diving"                          "gk_handling"
#  [65] "gk_kicking"                         "gk_positioning"
#  [67] "gk_reflexes"                        "rs"
#  [69] "rw"                                 "rf"
#  [71] "ram"                                "rcm"
#  [73] "rm"                                 "rdm"
#  [75] "rcb"                                "rb"
#  [77] "rwb"                                "st"
#  [79] "lw"                                 "cf"
#  [81] "cam"                                "cm"
#  [83] "lm"                                 "cdm"
#  [85] "cb"                                 "lb"
#  [87] "lwb"                                "ls"
#  [89] "lf"                                 "lam"
#  [91] "lcm"                                "ldm"
#  [93] "lcb"                                "gk"
#  [95] "1_on_1_rush_trait"                  "acrobatic_clearance_trait"
#  [97] "argues_with_officials_trait"        "avoids_using_weaker_foot_trait"
#  [99] "backs_into_player_trait"            "bicycle_kicks_trait"
# [101] "cautious_with_crosses_trait"        "chip_shot_trait"
# [103] "chipped_penalty_trait"              "comes_for_crosses_trait"
# [105] "corner_specialist_trait"            "diver_trait"
# [107] "dives_into_tackles_trait"           "diving_header_trait"
# [109] "driven_pass_trait"                  "early_crosser_trait"
# [111] "fan's_favourite_trait"              "fancy_flicks_trait"
# [113] "finesse_shot_trait"                 "flair_trait"
# [115] "flair_passes_trait"                 "gk_flat_kick_trait"
# [117] "gk_long_throw_trait"                "gk_up_for_corners_trait"
# [119] "giant_throw_in_trait"               "inflexible_trait"
# [121] "injury_free_trait"                  "injury_prone_trait"
# [123] "leadership_trait"                   "long_passer_trait"
# [125] "long_shot_taker_trait"              "long_throw_in_trait"
# [127] "one_club_player_trait"              "outside_foot_shot_trait"
# [129] "playmaker_trait"                    "power_free_kick_trait"
# [131] "power_header_trait"                 "puncher_trait"
# [133] "rushes_out_of_goal_trait"           "saves_with_feet_trait"
# [135] "second_wind_trait"                  "selfish_trait"
# [137] "skilled_dribbling_trait"            "stutter_penalty_trait"
# [139] "swerve_pass_trait"                  "takes_finesse_free_kicks_trait"
# [141] "target_forward_trait"               "team_player_trait"
# [143] "technical_dribbler_trait"           "tries_to_beat_defensive_line_trait"
# [145] "poacher_speciality"                 "speedster_speciality"
# [147] "aerial_threat_speciality"           "dribbler_speciality"
# [149] "playmaker_speciality"               "engine_speciality"
# [151] "distance_shooter_speciality"        "crosser_speciality"
# [153] "free_kick_specialist_speciality"    "tackling_speciality"
# [155] "tactician_speciality"               "acrobat_speciality"
# [157] "strength_speciality"                "clinical_finisher_speciality"
# [159] "prefers_rs"                         "prefers_rw"
# [161] "prefers_rf"                         "prefers_ram"
# [163] "prefers_rcm"                        "prefers_rm"
# [165] "prefers_rdm"                        "prefers_rcb"
# [167] "prefers_rb"                         "prefers_rwb"
# [169] "prefers_st"                         "prefers_lw"
# [171] "prefers_cf"                         "prefers_cam"
# [173] "prefers_cm"                         "prefers_lm"
# [175] "prefers_cdm"                        "prefers_cb"
# [177] "prefers_lb"                         "prefers_lwb"
# [179] "prefers_ls"                         "prefers_lf"
# [181] "prefers_lam"                        "prefers_lcm"
# [183] "prefers_ldm"                        "prefers_lcb"
# [185] "prefers_gk"

# %%
dim(FullData)
# Out:
# [1] 17994   185

# %%
library(knitr)

# %%
kable(head(FullData))
# Out:
# |     ID|name              |full_name                    |club                |club_logo                               | special| age|league                   |birth_date | height_cm| weight_kg|body_type  |real_face |flag                                   |nationality |photo                                        | eur_value| eur_wage| eur_release_clause| overall| potential| pac| sho| pas| dri| def| phy| international_reputation| skill_moves| weak_foot|work_rate_att |work_rate_def |preferred_foot | crossing| finishing| heading_accuracy| short_passing| volleys| dribbling| curve| free_kick_accuracy| long_passing| ball_control| acceleration| sprint_speed| agility| reactions| balance| shot_power| jumping| stamina| strength| long_shots| aggression| interceptions| positioning| vision| penalties| composure| marking| standing_tackle| sliding_tackle| gk_diving| gk_handling| gk_kicking| gk_positioning| gk_reflexes| rs| rw| rf| ram| rcm| rm| rdm| rcb| rb| rwb| st| lw| cf| cam| cm| lm| cdm| cb| lb| lwb| ls| lf| lam| lcm| ldm| lcb| gk|1_on_1_rush_trait |acrobatic_clearance_trait |argues_with_officials_trait |avoids_using_weaker_foot_trait |backs_into_player_trait |bicycle_kicks_trait |cautious_with_crosses_trait |chip_shot_trait |chipped_penalty_trait |comes_for_crosses_trait |corner_specialist_trait |diver_trait |dives_into_tackles_trait |diving_header_trait |driven_pass_trait |early_crosser_trait |fan's_favourite_trait |fancy_flicks_trait |finesse_shot_trait |flair_trait |flair_passes_trait |gk_flat_kick_trait |gk_long_throw_trait |gk_up_for_corners_trait |giant_throw_in_trait |inflexible_trait |injury_free_trait |injury_prone_trait |leadership_trait |long_passer_trait |long_shot_taker_trait |long_throw_in_trait |one_club_player_trait |outside_foot_shot_trait |playmaker_trait |power_free_kick_trait |power_header_trait |puncher_trait |rushes_out_of_goal_trait |saves_with_feet_trait |second_wind_trait |selfish_trait |skilled_dribbling_trait |stutter_penalty_trait |swerve_pass_trait |takes_finesse_free_kicks_trait |target_forward_trait |team_player_trait |technical_dribbler_trait |tries_to_beat_defensive_line_trait |poacher_speciality |speedster_speciality |aerial_threat_speciality |dribbler_speciality |playmaker_speciality |engine_speciality |distance_shooter_speciality |crosser_speciality |free_kick_specialist_speciality |tackling_speciality |tactician_speciality |acrobat_speciality |strength_speciality |clinical_finisher_speciality |prefers_rs |prefers_rw |prefers_rf |prefers_ram |prefers_rcm |prefers_rm |prefers_rdm |prefers_rcb |prefers_rb |prefers_rwb |prefers_st |prefers_lw |prefers_cf |prefers_cam |prefers_cm |prefers_lm |prefers_cdm |prefers_cb |prefers_lb |prefers_lwb |prefers_ls |prefers_lf |prefers_lam |prefers_lcm |prefers_ldm |prefers_lcb |prefers_gk |
# |------:|:-----------------|:----------------------------|:-------------------|:---------------------------------------|-------:|---:|:------------------------|:----------|---------:|---------:|:----------|:---------|:--------------------------------------|:-----------|:--------------------------------------------|---------:|--------:|------------------:|-------:|---------:|---:|---:|---:|---:|---:|---:|------------------------:|-----------:|---------:|:-------------|:-------------|:--------------|--------:|---------:|----------------:|-------------:|-------:|---------:|-----:|------------------:|------------:|------------:|------------:|------------:|-------:|---------:|-------:|----------:|-------:|-------:|--------:|----------:|----------:|-------------:|-----------:|------:|---------:|---------:|-------:|---------------:|--------------:|---------:|-----------:|----------:|--------------:|-----------:|--:|--:|--:|---:|---:|--:|---:|---:|--:|---:|--:|--:|--:|---:|--:|--:|---:|--:|--:|---:|--:|--:|---:|---:|---:|---:|--:|:-----------------|:-------------------------|:---------------------------|:------------------------------|:-----------------------|:-------------------|:---------------------------|:---------------|:---------------------|:-----------------------|:-----------------------|:-----------|:------------------------|:-------------------|:-----------------|:-------------------|:---------------------|:------------------|:------------------|:-----------|:------------------|:------------------|:-------------------|:-----------------------|:--------------------|:----------------|:-----------------|:------------------|:----------------|:-----------------|:---------------------|:-------------------|:---------------------|:-----------------------|:---------------|:---------------------|:------------------|:-------------|:------------------------|:---------------------|:-----------------|:-------------|:-----------------------|:---------------------|:-----------------|:------------------------------|:--------------------|:-----------------|:------------------------|:----------------------------------|:------------------|:--------------------|:------------------------|:-------------------|:--------------------|:-----------------|:---------------------------|:------------------|:-------------------------------|:-------------------|:--------------------|:------------------|:-------------------|:----------------------------|:----------|:----------|:----------|:-----------|:-----------|:----------|:-----------|:-----------|:----------|:-----------|:----------|:----------|:----------|:-----------|:----------|:----------|:-----------|:----------|:----------|:-----------|:----------|:----------|:-----------|:-----------|:-----------|:-----------|:----------|
# |  20801|Cristiano Ronaldo |C. Ronaldo dos Santos Aveiro |Real Madrid CF      |https://cdn.sofifa.org/18/teams/243.png |    2228|  32|Spanish Primera División |1985-02-05 |       185|        80|C. Ronaldo |TRUE      |https://cdn.sofifa.org/flags/38@3x.png |Portugal    |https://cdn.sofifa.org/18/players/20801.png  |  9.55e+07|   565000|          195800000|      94|        94|  90|  93|  82|  90|  33|  80|                        5|           5|         4|High          |Low           |Right          |       85|        94|               88|            83|      88|        91|    81|                 76|           77|           93|           89|           91|      89|        96|      63|         94|      95|      92|       80|         92|         63|            29|          95|     85|        85|        95|      22|              31|             23|         7|          11|         15|             14|          11| 92| 91| 91|  89|  82| 89|  62|  53| 61|  66| 92| 91| 91|  89| 82| 89|  62| 53| 61|  66| 92| 91|  89|  82|  62|  53| NA|FALSE             |FALSE                     |FALSE                       |FALSE                          |FALSE                   |FALSE               |FALSE                       |FALSE           |FALSE                 |FALSE                   |FALSE                   |FALSE       |FALSE                    |FALSE               |FALSE             |FALSE               |FALSE                 |FALSE              |FALSE              |TRUE        |FALSE              |FALSE              |FALSE               |FALSE                   |FALSE                |FALSE            |FALSE             |FALSE              |FALSE            |FALSE             |TRUE                  |FALSE               |FALSE                 |FALSE                   |FALSE           |TRUE                  |FALSE              |FALSE         |FALSE                    |FALSE                 |FALSE             |FALSE         |TRUE                    |FALSE                 |FALSE             |FALSE                          |FALSE                |FALSE             |FALSE                    |FALSE                              |FALSE              |TRUE                 |FALSE                    |TRUE                |FALSE                |FALSE             |TRUE                        |FALSE              |FALSE                           |FALSE               |FALSE                |TRUE               |FALSE               |TRUE                         |FALSE      |FALSE      |FALSE      |FALSE       |FALSE       |FALSE      |FALSE       |FALSE       |FALSE      |FALSE       |TRUE       |TRUE       |FALSE      |FALSE       |FALSE      |FALSE      |FALSE       |FALSE      |FALSE      |FALSE       |FALSE      |FALSE      |FALSE       |FALSE       |FALSE       |FALSE       |FALSE      |
# | 158023|L. Messi          |Lionel Messi                 |FC Barcelona        |https://cdn.sofifa.org/18/teams/241.png |    2158|  30|Spanish Primera División |1987-06-24 |       170|        72|Messi      |TRUE      |https://cdn.sofifa.org/flags/52@3x.png |Argentina   |https://cdn.sofifa.org/18/players/158023.png |  1.05e+08|   565000|          215300000|      93|        93|  89|  90|  86|  96|  26|  61|                        5|           4|         4|Medium        |Medium        |Left           |       77|        95|               71|            88|      85|        97|    89|                 90|           87|           95|           92|           87|      90|        95|      95|         85|      68|      73|       59|         88|         48|            22|          93|     90|        78|        96|      13|              28|             26|         6|          11|         15|             14|           8| 88| 91| 92|  92|  84| 90|  59|  45| 57|  62| 88| 91| 92|  92| 84| 90|  59| 45| 57|  62| 88| 92|  92|  84|  59|  45| NA|FALSE             |FALSE                     |FALSE                       |FALSE                          |FALSE                   |FALSE               |FALSE                       |TRUE            |FALSE                 |FALSE                   |FALSE                   |FALSE       |FALSE                    |FALSE               |FALSE             |FALSE               |FALSE                 |FALSE              |TRUE               |FALSE       |FALSE              |FALSE              |FALSE               |FALSE                   |FALSE                |FALSE            |FALSE             |FALSE              |FALSE            |FALSE             |TRUE                  |FALSE               |TRUE                  |FALSE                   |TRUE            |FALSE                 |FALSE              |FALSE         |FALSE                    |FALSE                 |FALSE             |FALSE         |TRUE                    |FALSE                 |FALSE             |FALSE                          |FALSE                |FALSE             |FALSE                    |FALSE                              |FALSE              |FALSE                |FALSE                    |TRUE                |FALSE                |FALSE             |FALSE                       |FALSE              |TRUE                            |FALSE               |FALSE                |TRUE               |FALSE               |TRUE                         |FALSE      |TRUE       |FALSE      |FALSE       |FALSE       |FALSE      |FALSE       |FALSE       |FALSE      |FALSE       |TRUE       |FALSE      |TRUE       |FALSE       |FALSE      |FALSE      |FALSE       |FALSE      |FALSE      |FALSE       |FALSE      |FALSE      |FALSE       |FALSE       |FALSE       |FALSE       |FALSE      |
# | 190871|Neymar            |Neymar da Silva Santos Jr.   |Paris Saint-Germain |https://cdn.sofifa.org/18/teams/73.png  |    2100|  25|French Ligue 1           |1992-02-05 |       175|        68|Neymar     |TRUE      |https://cdn.sofifa.org/flags/54@3x.png |Brazil      |https://cdn.sofifa.org/18/players/190871.png |  1.23e+08|   280000|          236800000|      92|        94|  92|  84|  79|  95|  30|  60|                        5|           5|         5|High          |Medium        |Right          |       75|        89|               62|            81|      83|        96|    81|                 84|           75|           95|           94|           90|      96|        88|      82|         80|      61|      78|       53|         77|         56|            36|          90|     80|        81|        92|      21|              24|             33|         9|           9|         15|             15|          11| 84| 89| 88|  88|  79| 87|  59|  46| 59|  64| 84| 89| 88|  88| 79| 87|  59| 46| 59|  64| 84| 88|  88|  79|  59|  46| NA|FALSE             |FALSE                     |FALSE                       |FALSE                          |FALSE                   |FALSE               |FALSE                       |FALSE           |FALSE                 |FALSE                   |FALSE                   |TRUE        |FALSE                    |FALSE               |FALSE             |FALSE               |FALSE                 |FALSE              |FALSE              |TRUE        |FALSE              |FALSE              |FALSE               |FALSE                   |FALSE                |FALSE            |FALSE             |FALSE              |FALSE            |FALSE             |FALSE                 |FALSE               |FALSE                 |FALSE                   |FALSE           |FALSE                 |FALSE              |FALSE         |FALSE                    |FALSE                 |FALSE             |FALSE         |TRUE                    |FALSE                 |FALSE             |TRUE                           |FALSE                |FALSE             |TRUE                     |FALSE                              |FALSE              |TRUE                 |FALSE                    |TRUE                |FALSE                |FALSE             |FALSE                       |FALSE              |FALSE                           |FALSE               |FALSE                |TRUE               |FALSE               |FALSE                        |FALSE      |FALSE      |FALSE      |FALSE       |FALSE       |FALSE      |FALSE       |FALSE       |FALSE      |FALSE       |FALSE      |TRUE       |FALSE      |FALSE       |FALSE      |FALSE      |FALSE       |FALSE      |FALSE      |FALSE       |FALSE      |FALSE      |FALSE       |FALSE       |FALSE       |FALSE       |FALSE      |
# | 176580|L. Suárez         |Luis Suárez                  |FC Barcelona        |https://cdn.sofifa.org/18/teams/241.png |    2291|  30|Spanish Primera División |1987-01-24 |       182|        86|Normal     |TRUE      |https://cdn.sofifa.org/flags/60@3x.png |Uruguay     |https://cdn.sofifa.org/18/players/176580.png |  9.70e+07|   510000|          198900000|      92|        92|  82|  90|  79|  87|  42|  81|                        5|           4|         4|High          |Medium        |Right          |       77|        94|               77|            83|      88|        86|    86|                 84|           64|           91|           88|           77|      86|        93|      60|         87|      69|      89|       80|         86|         78|            41|          92|     84|        85|        83|      30|              45|             38|        27|          25|         31|             33|          37| 88| 87| 88|  87|  80| 85|  65|  58| 64|  68| 88| 87| 88|  87| 80| 85|  65| 58| 64|  68| 88| 88|  87|  80|  65|  58| NA|FALSE             |FALSE                     |FALSE                       |FALSE                          |FALSE                   |FALSE               |FALSE                       |FALSE           |FALSE                 |FALSE                   |FALSE                   |TRUE        |FALSE                    |FALSE               |FALSE             |FALSE               |FALSE                 |FALSE              |FALSE              |FALSE       |FALSE              |FALSE              |FALSE               |FALSE                   |FALSE                |FALSE            |FALSE             |FALSE              |FALSE            |FALSE             |FALSE                 |FALSE               |FALSE                 |FALSE                   |FALSE           |FALSE                 |FALSE              |FALSE         |FALSE                    |FALSE                 |FALSE             |FALSE         |FALSE                   |FALSE                 |FALSE             |FALSE                          |FALSE                |FALSE             |TRUE                     |TRUE                               |FALSE              |FALSE                |FALSE                    |FALSE               |FALSE                |FALSE             |FALSE                       |FALSE              |FALSE                           |FALSE               |FALSE                |TRUE               |FALSE               |TRUE                         |FALSE      |FALSE      |FALSE      |FALSE       |FALSE       |FALSE      |FALSE       |FALSE       |FALSE      |FALSE       |TRUE       |FALSE      |FALSE      |FALSE       |FALSE      |FALSE      |FALSE       |FALSE      |FALSE      |FALSE       |FALSE      |FALSE      |FALSE       |FALSE       |FALSE       |FALSE       |FALSE      |
# | 167495|M. Neuer          |Manuel Neuer                 |FC Bayern Munich    |https://cdn.sofifa.org/18/teams/21.png  |    1493|  31|German Bundesliga        |1986-03-27 |       193|        92|Normal     |TRUE      |https://cdn.sofifa.org/flags/21@3x.png |Germany     |https://cdn.sofifa.org/18/players/167495.png |  6.10e+07|   230000|          100700000|      92|        92|  91|  90|  95|  89|  60|  91|                        5|           1|         4|Medium        |Medium        |Right          |       15|        13|               25|            55|      11|        30|    14|                 11|           59|           48|           58|           61|      52|        85|      35|         25|      78|      44|       83|         16|         29|            30|          12|     70|        47|        70|      10|              10|             11|        91|          90|         95|             91|          89| NA| NA| NA|  NA|  NA| NA|  NA|  NA| NA|  NA| NA| NA| NA|  NA| NA| NA|  NA| NA| NA|  NA| NA| NA|  NA|  NA|  NA|  NA| 92|TRUE              |FALSE                     |FALSE                       |FALSE                          |FALSE                   |FALSE               |FALSE                       |FALSE           |FALSE                 |TRUE                    |FALSE                   |FALSE       |FALSE                    |FALSE               |FALSE             |FALSE               |FALSE                 |FALSE              |FALSE              |FALSE       |FALSE              |FALSE              |TRUE                |FALSE                   |FALSE                |FALSE            |FALSE             |FALSE              |FALSE            |FALSE             |FALSE                 |FALSE               |FALSE                 |FALSE                   |FALSE           |FALSE                 |FALSE              |FALSE         |TRUE                     |FALSE                 |FALSE             |FALSE         |FALSE                   |FALSE                 |FALSE             |FALSE                          |FALSE                |FALSE             |FALSE                    |FALSE                              |FALSE              |FALSE                |FALSE                    |FALSE               |FALSE                |FALSE             |FALSE                       |FALSE              |FALSE                           |FALSE               |FALSE                |FALSE              |FALSE               |FALSE                        |FALSE      |FALSE      |FALSE      |FALSE       |FALSE       |FALSE      |FALSE       |FALSE       |FALSE      |FALSE       |FALSE      |FALSE      |FALSE      |FALSE       |FALSE      |FALSE      |FALSE       |FALSE      |FALSE      |FALSE       |FALSE      |FALSE      |FALSE       |FALSE       |FALSE       |FALSE       |TRUE       |
# | 188545|R. Lewandowski    |Robert Lewandowski           |FC Bayern Munich    |https://cdn.sofifa.org/18/teams/21.png  |    2146|  28|German Bundesliga        |1988-08-21 |       185|        79|Normal     |TRUE      |https://cdn.sofifa.org/flags/37@3x.png |Poland      |https://cdn.sofifa.org/18/players/188545.png |  9.20e+07|   355000|          151800000|      91|        91|  81|  88|  75|  86|  38|  82|                        4|           3|         4|High          |Medium        |Right          |       62|        91|               85|            83|      87|        85|    77|                 84|           65|           89|           79|           83|      78|        91|      80|         88|      84|      79|       84|         83|         80|            39|          91|     78|        84|        87|      25|              42|             19|        15|           6|         12|              8|          10| 88| 84| 87|  84|  78| 82|  62|  57| 58|  61| 88| 84| 87|  84| 78| 82|  62| 57| 58|  61| 88| 87|  84|  78|  62|  57| NA|FALSE             |FALSE                     |FALSE                       |FALSE                          |FALSE                   |FALSE               |FALSE                       |TRUE            |FALSE                 |FALSE                   |FALSE                   |FALSE       |FALSE                    |FALSE               |FALSE             |FALSE               |FALSE                 |FALSE              |TRUE               |FALSE       |FALSE              |FALSE              |FALSE               |FALSE                   |FALSE                |FALSE            |TRUE              |FALSE              |FALSE            |FALSE             |FALSE                 |FALSE               |FALSE                 |FALSE                   |FALSE           |FALSE                 |FALSE              |FALSE         |FALSE                    |FALSE                 |FALSE             |FALSE         |FALSE                   |FALSE                 |FALSE             |FALSE                          |FALSE                |FALSE             |FALSE                    |FALSE                              |FALSE              |FALSE                |FALSE                    |FALSE               |FALSE                |FALSE             |FALSE                       |FALSE              |FALSE                           |FALSE               |FALSE                |FALSE              |FALSE               |TRUE                         |FALSE      |FALSE      |FALSE      |FALSE       |FALSE       |FALSE      |FALSE       |FALSE       |FALSE      |FALSE       |TRUE       |FALSE      |FALSE      |FALSE       |FALSE      |FALSE      |FALSE       |FALSE      |FALSE      |FALSE       |FALSE      |FALSE      |FALSE       |FALSE       |FALSE       |FALSE       |FALSE      |

# %%
library(ggplot2)

# %%
ggplot(FullData, aes(age, fill = age)) +
geom_density(position = "stack")
# Out:
# plot without title

# %%
FullData %>% 
  ggplot(aes(x = overall, fill = factor(overall))) +
  geom_bar(color = "grey20") + guides(fill = FALSE)+
  labs(title="Player's Overall ")
# Out:
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# plot without title

# %%
agerating <- FullData[age<41,.("overall"=mean(overall)),by=age][order(-age)]
ggplot(data = agerating,aes(x=age,y=overall))+
  geom_line(color="red",size=2)+labs(title="Rating vs Age")+
  annotate("text", x = 30, y = max(agerating$overall),color="blue", label = "Max", parse = TRUE, size = 3)
# Out:
# plot without title

# %%
install.packages("DT")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library(data.table)

# %%
install.packages("data.table")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
#       name              age overall club                   eur_value
# 1     Cristiano Ronaldo 32  94      Real Madrid CF         9.55e+07
# 2     L. Messi          30  93      FC Barcelona           1.05e+08
# 3     Neymar            25  92      Paris Saint-Germain    1.23e+08
# 4     L. Suárez         30  92      FC Barcelona           9.70e+07
# 5     M. Neuer          31  92      FC Bayern Munich       6.10e+07
# 6     R. Lewandowski    28  91      FC Bayern Munich       9.20e+07
# 7     De Gea            26  90      Manchester United      6.45e+07
# 8     E. Hazard         26  90      Chelsea                9.05e+07
# 9     T. Kroos          27  90      Real Madrid CF         7.90e+07
# 10    G. Higuaín        29  90      Juventus               7.70e+07
# 11    Sergio Ramos      31  90      Real Madrid CF         5.20e+07
# 12    K. De Bruyne      26  89      Manchester City        8.30e+07
# 13    T. Courtois       25  89      Chelsea                5.90e+07
# 14    A. Sánchez        28  89      Arsenal                6.75e+07
# 15    L. Modrić         31  89      Real Madrid CF         5.70e+07
# 16    G. Bale           27  89      Real Madrid CF         6.95e+07
# 17    S. Agüero         29  89      Manchester City        6.65e+07
# 18    G. Chiellini      32  89      Juventus               3.80e+07
# 19    G. Buffon         39  89      Juventus               4.50e+06
# 20    P. Dybala         23  88      Juventus               7.90e+07
# 21    J. Oblak          24  88      Atlético Madrid        5.70e+07
# 22    A. Griezmann      26  88      Atlético Madrid        7.50e+07
# 23    Thiago            26  88      FC Bayern Munich       7.05e+07
# 24    P. Aubameyang     28  88      Borussia Dortmund      6.10e+07
# 25    L. Bonucci        30  88      Milan                  4.40e+07
# 26    J. Boateng        28  88      FC Bayern Munich       4.80e+07
# 27    D. Godín          31  88      Atlético Madrid        4.00e+07
# 28    M. Hummels        28  88      FC Bayern Munich       4.80e+07
# 29    M. Özil           28  88      Arsenal                6.00e+07
# 30    H. Lloris         30  88      Tottenham Hotspur      3.80e+07
# ...   ...               ... ...     ...                    ...
# 17965 T. Robinson       19  48      Bradford City          60000
# 17966 D. Clarke         20  48      Shamrock Rovers        50000
# 17967 R. Hughes         18  48      Hamilton Academical FC 60000
# 17968 Z. Mohammed       17  48      Accrington Stanley     50000
# 17969 D. Peppard        17  47      Bohemian FC            50000
# 17970 C. Rogers         17  47      Bray Wanderers         40000
# 17971 N. McLaughlin     18  47      Partick Thistle F.C.   60000
# 17972 G. Manley         19  47      Cork City              50000
# 17973 P. Phillips       18  47      Cork City              60000
# 17974 A. Byrne          18  47      Cork City              60000
# 17975 K. Fujikawa       18  47      Júbilo Iwata           60000
# 17976 K. Egan           19  47      Exeter City            60000
# 17977 T. Brownsword     17  47      Morecambe              60000
# 17978 F. Prohart        18  47      Wolfsberger AC         60000
# 17979 L. Jones          18  47      Doncaster Rovers       50000
# 17980 A. Kilgour        19  47      Bristol Rovers         40000
# 17981 R. White          18  47      Bolton Wanderers       60000
# 17982 A. Conway         19  47      Galway United          60000
# 17983 H. Clifton        19  46      Grimsby Town           60000
# 17984 M. Whelan         18  46      Galway United          40000
# 17985 T. Sawyer         18  46      Grimsby Town           50000
# 17986 J. Keeble         18  46      Grimsby Town           40000
# 17987 K. McKenzie-Lyle  19  46      Barnet                 30000
# 17988 N. Sheron         19  46      Fleetwood Town         60000
# 17989 T. Käßemodel      28  46      FC Erzgebirge Aue      30000
# 17990 A. Kelsey         17  46      Scunthorpe United      50000
# 17991 B. Richardson     47  46      Wycombe Wanderers          0
# 17992 J. Young          17  46      Swindon Town           60000
# 17993 J. Lundstram      18  46      Crewe Alexandra        60000
# 17994 L. Sackey         18  46      Scunthorpe United      50000
#       class                   escape options
# 1     nowrap hover row-border FALSE  t
# 2     nowrap hover row-border FALSE  TRUE
# 3     nowrap hover row-border FALSE  TRUE
# 4     nowrap hover row-border FALSE  t
# 5     nowrap hover row-border FALSE  TRUE
# 6     nowrap hover row-border FALSE  TRUE
# 7     nowrap hover row-border FALSE  t
# 8     nowrap hover row-border FALSE  TRUE
# 9     nowrap hover row-border FALSE  TRUE
# 10    nowrap hover row-border FALSE  t
# 11    nowrap hover row-border FALSE  TRUE
# 12    nowrap hover row-border FALSE  TRUE
# 13    nowrap hover row-border FALSE  t
# 14    nowrap hover row-border FALSE  TRUE
# 15    nowrap hover row-border FALSE  TRUE
# 16    nowrap hover row-border FALSE  t
# 17    nowrap hover row-border FALSE  TRUE
# 18    nowrap hover row-border FALSE  TRUE
# 19    nowrap hover row-border FALSE  t
# 20    nowrap hover row-border FALSE  TRUE
# 21    nowrap hover row-border FALSE  TRUE
# 22    nowrap hover row-border FALSE  t
# 23    nowrap hover row-border FALSE  TRUE
# 24    nowrap hover row-border FALSE  TRUE
# 25    nowrap hover row-border FALSE  t
# 26    nowrap hover row-border FALSE  TRUE
# 27    nowrap hover row-border FALSE  TRUE
# 28    nowrap hover row-border FALSE  t
# 29    nowrap hover row-border FALSE  TRUE
# 30    nowrap hover row-border FALSE  TRUE
# ...   ...                     ...    ...
# 17965 nowrap hover row-border FALSE  t
# 17966 nowrap hover row-border FALSE  TRUE
# 17967 nowrap hover row-border FALSE  TRUE
# 17968 nowrap hover row-border FALSE  t
# 17969 nowrap hover row-border FALSE  TRUE
# 17970 nowrap hover row-border FALSE  TRUE
# 17971 nowrap hover row-border FALSE  t
# 17972 nowrap hover row-border FALSE  TRUE
# 17973 nowrap hover row-border FALSE  TRUE
# 17974 nowrap hover row-border FALSE  t
# 17975 nowrap hover row-border FALSE  TRUE
# 17976 nowrap hover row-border FALSE  TRUE
# 17977 nowrap hover row-border FALSE  t
# 17978 nowrap hover row-border FALSE  TRUE
# 17979 nowrap hover row-border FALSE  TRUE
# 17980 nowrap hover row-border FALSE  t
# 17981 nowrap hover row-border FALSE  TRUE
# 17982 nowrap hover row-border FALSE  TRUE
# 17983 nowrap hover row-border FALSE  t
# 17984 nowrap hover row-border FALSE  TRUE
# 17985 nowrap hover row-border FALSE  TRUE
# 17986 nowrap hover row-border FALSE  t
# 17987 nowrap hover row-border FALSE  TRUE
# 17988 nowrap hover row-border FALSE  TRUE
# 17989 nowrap hover row-border FALSE  t
# 17990 nowrap hover row-border FALSE  TRUE
# 17991 nowrap hover row-border FALSE  TRUE
# 17992 nowrap hover row-border FALSE  t
# 17993 nowrap hover row-border FALSE  TRUE
# 17994 nowrap hover row-border FALSE  TRUE

# %%
FullData %>% 
  ggplot(aes(x = height_cm, fill = factor(height_cm))) +
  geom_bar(color = "grey20") + guides(fill = FALSE)+
  labs(title="Players Height")
# Out:
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# plot without title

# %%
FullData %>% 
  ggplot(aes(x = weight_kg, fill = factor(weight_kg))) +
  geom_bar(color = "grey20") + guides(fill = FALSE)+
  labs(title="Players Weight")
# Out:
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# plot without title

# %%
Nationalitys <- FullData[FullData$nationality!="",.N,by=.(nationality,`flag`)][order(-N)]

Nationalitys = Nationalitys[,c(1,3)] 
head(Nationalitys[order(Nationalitys$N, decreasing = TRUE),],10)
# Out:
#    nationality N
# 1  England     1631
# 2  Germany     1147
# 3  Spain       1020
# 4  France       966
# 5  Argentina    962
# 6  Brazil       806
# 7  Italy        800
# 8  Colombia     593
# 9  Japan        471
# 10 Netherlands  430

# %%
TeamDF<-arrange(FullData[, list(Avg=mean(overall)), by= "club" ], desc(Avg) )

kable(head(TeamDF, 10))
# Out:
# |club                |      Avg|
# |:-------------------|--------:|
# |FC Barcelona        | 82.75000|
# |Juventus            | 81.69231|
# |Real Madrid CF      | 79.85714|
# |FC Bayern Munich    | 79.15385|
# |Paris Saint-Germain | 77.96429|
# |Manchester United   | 77.78788|
# |Napoli              | 77.70370|
# |Roma                | 77.37037|
# |Sevilla FC          | 77.00000|
# |Inter               | 76.70833|

# %%
cluster = FullData[,c(7,10,11,17:29,34:94)]
cluster[is.na(cluster)] = 0
wss <- (nrow(cluster[,c()])-1)*sum(apply(cluster[,1:ncol(cluster)],2,var))

for (i in 2:10) 
  wss[i] <- sum(kmeans(cluster[,1:ncol(cluster)], centers=i)$withinss)

plot(1:
       10, wss, type="b", xlab="Number of Cluster",  ylab="Squares Summatory")
# Out:
# plot without title

# %%
library("mclust")

# %%
install.packages("cluster")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
install.packages("factoextra")
# Out:
# also installing the dependencies ‘processx’, ‘callr’, ‘desc’, ‘pkgload’, ‘waldo’, ‘testthat’, ‘MatrixModels’, ‘sp’, ‘minqa’, ‘nloptr’, ‘RcppEigen’, ‘cpp11’, ‘pbkrtest’, ‘quantreg’, ‘maptools’, ‘lme4’, ‘tidyr’, ‘broom’, ‘corrplot’, ‘car’, ‘ellipse’, ‘flashClust’, ‘leaps’, ‘scatterplot3d’, ‘ggsci’, ‘ggsignif’, ‘polynom’, ‘rstatix’, ‘dendextend’, ‘FactoMineR’, ‘ggpubr’, ‘ggrepel’

# %%
install.packages("fpc")
# Out:
# also installing the dependency ‘kernlab’
#
# Warning message in install.packages("fpc"):
# “installation of package ‘kernlab’ had non-zero exit status”Warning message in install.packages("fpc"):
# “installation of package ‘fpc’ had non-zero exit status”Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library(fpc)
set.seed(123)
km<-kmeans(cluster[,1:ncol(cluster)],4)
cluster$grupo<-km$cluster
FullData$grupo <-km$cluster
g1<- FullData[FullData$grupo==1,]
g2<- FullData[FullData$grupo==2,]
g3<- FullData[FullData$grupo==3,]
g4<- FullData[FullData$grupo==4,]

plotcluster(cluster[,1:(ncol(cluster)-1)],km$cluster)
# Out:
# Error in library(fpc): there is no package called ‘fpc’
# Traceback:
#
# 1. library(fpc)

# %%
df <- read.csv("fifa21_male2.csv", stringsAsFactors = FALSE)

head(df)
# Out:
#   ID Name        Age OVA Nationality           Club             BOV BP
# 1  2 G. Pasquale 33  69  Italy                 Udinese          71  LWB
# 2 16 Luis García 37  71  Spain                 KAS Eupen        70  CM
# 3 27 J. Cole     33  71  England               Coventry City    71  CAM
# 4 36 D. Yorke    36  68  Trinidad &amp; Tobago Sunderland       70  ST
# 5 41 Iniesta     36  81  Spain                 Vissel Kobe      82  CAM
# 6 61 D. Odonkor  27  66  Germany               Alemannia Aachen 66  RW
#   Position     Player.Photo                                      ... CDM
# 1 LM           https://cdn.sofifa.com/players/000/002/16_120.png ... 70+-1
# 2 CM CAM CDM   https://cdn.sofifa.com/players/000/016/19_120.png ... 66+1
# 3 CAM RM RW LM https://cdn.sofifa.com/players/000/027/16_120.png ... 54+0
# 4              https://cdn.sofifa.com/players/000/036/09_120.png ... 65+0
# 5 CM CAM       https://cdn.sofifa.com/players/000/041/20_120.png ... 73+3
# 6 RW RM        https://cdn.sofifa.com/players/000/061/12_120.png ... 47+0
#   RDM   RWB   LB    LCB  CB   RCB  RB    GK   Gender
# 1 70+-1 71+-2 70+-1 69+0 69+0 69+0 70+-1 17+0 Male
# 2 66+1  62+1  60+1  60+1 60+1 60+1 60+1  17+1 Male
# 3 54+0  52+0  47+0  46+0 46+0 46+0 47+0  15+0 Male
# 4 65+0  56+0  57+0  51+0 51+0 51+0 57+0  22+0 Male
# 5 73+3  70+3  67+3  64+3 64+3 64+3 67+3  17+3 Male
# 6 47+0  50+0  46+0  41+0 41+0 41+0 46+0  13+0 Male

# %%
df2 <- suppressWarnings(df %>% 
    # Remove Retired Players
    separate(Contract, c("Contract1", "Contract2"), sep = " ~ ") %>%
    mutate_at(vars(Contract1:Contract2), funs(as.numeric)) %>%
    filter(Contract1 >= 2020 | Contract2 > 2020 ) %>%
    # Height & Weight Transformation (KG, CM)
    mutate(Height = round(
    as.numeric(str_sub(str_remove_all(Height, '"'), start = 1, end = 1))*30.48 + as.numeric(str_sub(str_remove_all(Height, '"'), start = 3, end = 5))* 2.54
    ),
           Weight = round(as.numeric(str_sub(Weight, start = 1, end = 3)) / 2.204623)) %>%
    # Create Position Class
    mutate(Class = case_when(
        
        BP %in% c("CB", "RB", "LB", "LWB", "RWB", "LCB", "RCB") ~ "Defence",
        BP == "GK" ~ "Goal Keeper",
        BP %in% c("CM", "CDM","CAM","LM","RM", "LAM", "RAM", "LCM", "RCM", "LDM", "RDM") ~ "Midfielder",
        TRUE ~ "Forward"
        
    )) %>%
    # Market Values & Wage
    mutate(
        Values = as.numeric(str_replace_all(str_remove_all(str_remove_all(Value,"€"), "M"), "K", "000")),
        Values = if_else(Values < 1000 , Values * 1000000, Values),
        Wages = as.numeric(str_replace_all(str_remove_all(Wage,"€"), "K", "000"))

    ))


head(df2)
# Out:
#   ID   Name            Age OVA Nationality         Club           BOV BP
# 1   41 Iniesta         36  81  Spain               Vissel Kobe    82  CAM
# 2  330 R. Keane        35  80  Republic of Ireland LA Galaxy      81  CF
# 3 1179 G. Buffon       42  82  Italy               Juventus       82  GK
# 4 2147 M. Stekelenburg 37  72  Netherlands         Ajax           72  GK
# 5 2702 K. Ellison      41  58  England             Newport County 61  ST
# 6 3281 Tarantini       36  72  Portugal            Rio Ave FC     72  CM
#   Position Player.Photo                                      ... LB   LCB  CB
# 1 CM CAM   https://cdn.sofifa.com/players/000/041/20_120.png ... 67+3 64+3 64+3
# 2 ST       https://cdn.sofifa.com/players/000/330/17_120.png ... 52+1 47+1 47+1
# 3 GK       https://cdn.sofifa.com/players/001/179/20_120.png ... 26+3 29+3 29+3
# 4 GK       https://cdn.sofifa.com/players/002/147/20_120.png ... 26+2 30+2 30+2
# 5 LM ST    https://cdn.sofifa.com/players/002/702/20_120.png ... 48+2 53+2 53+2
# 6          https://cdn.sofifa.com/players/003/281/20_120.png ... 65+2 71+1 71+1
#   RCB  RB   GK   Gender Class       Values   Wages
# 1 64+3 67+3 17+3 Male   Midfielder       5.5 12000
# 2 47+1 52+1 20+1 Male   Forward          5.5 10000
# 3 29+3 26+3 80+2 Male   Goal Keeper      2.2 41000
# 4 30+2 26+2 71+1 Male   Goal Keeper 325000.0  5000
# 5 53+2 48+2 15+2 Male   Forward          0.0  2000
# 6 71+1 65+2 18+2 Male   Midfielder  975000.0  6000

# %%
pitch <- function(goaltype = c("box", "line", "barca_numbers"), pitch_theme = c("green","blue","night")){
  
  # Argüman Kontrolleri 
  if(is.null(goaltype) | missing("goaltype")){goaltype <- "box"}
  if(is.null(pitch_theme) | missing("pitch_theme")){pitch_theme <- "green"}
  
  # Saha Rengi
  if(pitch_theme == "green"){
    # Green
    background_color = "#77BD77"
    grass_color = "#77BD77"
    # Dark Green
    #background_color = "#538032"
    #grass_color = "#538032"
    line_color =  "#ffffff"
    goal_color = "#000000"
    
  }else if(pitch_theme == "blue"){
    
    # Blue
    grass_color = "#224C56" 
    line_color =  "#B3CED9" 
    background_color = "#224C56" 
    goal_color = "#15393D"
    
  }else if(pitch_theme == "night"){
    
    # Night
    grass_color = "#202020"
    line_color =  "#797876"
    background_color = "#202020"
    goal_color = "#131313"
  }else{
    return(NULL)
  }
  
  # Tüm Parametreler
  # Sahanın Boyutu
  ymin <- 0    # Minimum En
  ymax <- 80   # Maksimum En
  xmin <- 0    # Minimum Uzunluk
  xmax <- 120  # Maksimum Uzunluk
  
  # Saha Dışındaki Alan
  padding <- 5 # Default: 5
  
  # Ceza Sahasının Çizilmesi
  boxEdgeDef <- 18
  boxEdgeOff <- 102
  boxEdgeLeft <- 18
  boxEdgeRight <- 62
  
  # Yarı Saha Çizgisi
  halfwayline <- 60
  
  # Ceza Sahası İçerisinde Kale Önü Dikdörtgeni
  sixYardDef <- 6
  sixYardOff <- 114
  sixYardLeft <- 30
  sixYardRight <- 50
  
  # Yarı Saha Çemberi Parametreleri
  CentreSpot <- 40
  centreCirle_d <- 20
  
  # Yarı Saha Çember Fonksiyonu
  circleFun <- function(center = c(0,0),diameter = 1, npoints = 100){
    r = diameter / 2
    tt <- seq(0,2*pi,length.out = npoints)
    xx <- center[1] + r * cos(tt)
    yy <- center[2] + r * sin(tt)
    return(data.frame(x = xx, y = yy))
  }
  
  # Yarı Saha Çemberinin Oluşturulması
  center_circle <- circleFun(c(halfwayline,CentreSpot),centreCirle_d,npoints = 100)
  
  # Penaltı Noktası
  penSpotDef <- 12
  penSpotOff <- 108
  
  # Tema Argümanı size: 12
  size <- 12
  
  # Kale-Gol Çizgisi
  goalPostLeft <- 36
  goalPostRight <- 44
  
  
  # SAHANIN ÇİZDİRİLMESİ
  
  plot <- ggplot()+
    
    # 1. Futbol Sahasının Sınırları
    xlim(c(xmin-padding,xmax+padding)) + ylim(c(ymin-padding,ymax+padding))+
    
    # 2. Temanın Ayarlanması
    theme(
      # 2.1. Eksenlerdeki Yazıların ve Çizgilerin Kaldırılması 
      axis.text = element_blank(),
      axis.ticks = element_blank(),
      axis.title = element_blank(),
      
      # 2.2. Lejant Ayarlamaları
      legend.background = element_rect(fill = background_color, colour = NA), # Lejant Arka Planı (Saha Rengi ile Aynı Olmalı!)
      legend.key = element_rect(fill = background_color), # Lejant Arka Planı (Saha Rengi ile Aynı Olmalı!)
      legend.key.size = unit(1.2,"lines"), # Lejant Kutusunun Boyutu
      legend.text = element_text(size = size), # Lejant Yazısının Boyutu
      legend.title=element_text(size=size, face="bold",hjust=0), # Lejant Başlık Yazısının boyutu
      
      # 2.3. Facet Ayarlamaları - Arka Plan ve Yazıların Düzenlenmesi
      strip.background = element_rect(colour = background_color, fill = background_color, size = .5),
      strip.text.y=element_text(colour=background_color,size = size, angle=270),
      strip.text.x=element_text(size=size*1),
      
      # 2.4. Panel Ayarlamaları
      panel.background=element_rect(fill=background_color,colour=background_color), # Arka Plan 
      panel.grid = element_blank(), # Koordinat Çizgilerinin Silinmesi
      panel.spacing = element_blank(), # Facet İçin Birim Ayarlaması
      
      # 2.5. Plot Ayarlamaları
      plot.background=element_rect(background_color), # Tüm Görselin Arka Planı | element rect ile arkaplanı renk verilebilir
      plot.margin=unit(c(0, 0, 0, 0), "lines"), # Marjin Ayarlaması
      plot.title=element_text(size=size*1.2) # Plot Başlık Yazısının Boyutu
    )+
    
    # 3. Saha Çizgisi: Dikdörtgenin çizilmesi 
    geom_rect(aes(xmin=xmin, xmax=xmax, ymin=ymin, ymax=ymax), fill = NA, colour = line_color)+
    
    # 4. Ceza Sahası: Dikdörtgenin Çizilmesi
    geom_rect(aes(xmin=xmin, xmax=boxEdgeDef, ymin=boxEdgeLeft, ymax=boxEdgeRight), fill = grass_color, colour = line_color)+ # Sol Ceza Sahası
    geom_rect(aes(xmin=boxEdgeOff, xmax=xmax, ymin=boxEdgeLeft, ymax=boxEdgeRight), fill = grass_color, colour = line_color)+ # Sağ Ceza Sahası
    
    # 5. Yarı Saha Çizgisi
    geom_segment(aes(x = halfwayline, y = ymin, xend = halfwayline, yend = ymax),colour = line_color)+
    
    # 6. Ceza Sahası İçerisinde Kale Önü Dikdörtgeni
    geom_rect(aes(xmin=xmin, xmax=sixYardDef, ymin=sixYardLeft, ymax=sixYardRight), fill = grass_color, colour = line_color)+ # Sol
    geom_rect(aes(xmin=sixYardOff, xmax=xmax, ymin=sixYardLeft, ymax=sixYardRight), fill = grass_color, colour = line_color)+ # Sağ
    
    # 7. Yarı Saha Çemberi
    geom_path(data=center_circle, aes(x=x,y=y), colour = line_color)+
    
    # 8. Penaltı Noktalarının Çizilmesi
    geom_point(aes(x = penSpotDef , y = CentreSpot), colour = line_color, size = 0.9)+ # Sol
    geom_point(aes(x = penSpotOff , y = CentreSpot), colour = line_color, size = 0.9)+ # Sağ
    
    # 9. Başlangıç Noktasının Çizilmesi
    geom_point(aes(x = halfwayline , y = CentreSpot), colour = line_color)+
    
    # Ceza Yayının Çizilmesi
    
    annotate("path",
             x = 12 + 10 * cos(seq(-0.3*pi, 0.3*pi, length.out = 30)),
             y = 40 + 10 * sin(seq(-0.3*pi, 0.3*pi, length.out = 30)),
             col = line_color) +
    annotate("path",
             x = (120-12) - 10 * cos(seq(-0.3*pi, 0.3*pi, length.out = 30)),
             y = 40 + 10 * sin(seq(-0.3*pi, 0.3*pi, length.out = 30)),
             col = line_color)
  
  # 10. Kalenin Çizilmesi: Üç çeşit şekilde kale çeşitliliği yapılabilir.
  if(goaltype == "box"){
    
    plot <- plot+
      geom_rect(aes(xmin = xmin - 2 , ymin = goalPostLeft, xmax = xmin, ymax = goalPostRight), fill = grass_color, colour = line_color)+
      geom_rect(aes(xmin = xmax, ymin = goalPostLeft, xmax = xmax + 2, ymax = goalPostRight), fill = grass_color, colour = line_color)
    
  }else if(goaltype == "line"){
    
    plot <- plot+
      geom_segment(aes(x = xmin, y = goalPostLeft, xend = xmin, yend = goalPostRight),colour = goal_color, size = 1) + # Sol
      geom_segment(aes(x = xmax, y = goalPostLeft, xend = xmax, yend = goalPostRight),colour = goal_color, size = 1) # Sağ
    
  }else if(goaltype == "barca_numbers"){
    
    plot <- plot+
      geom_segment(aes(x = xmin - 0.75, y = goalPostLeft, xend = xmin - 0.75, yend = goalPostRight),colour = line_color, size = 0.75)+
      geom_segment(aes(x = xmax + 0.75, y = goalPostLeft, xend = xmax + 0.75, yend = goalPostRight),colour = line_color, size = 0.75)
    
  }else{
    return(NULL)
  }
  
  
  # 11. Korner Çizgileri
  TopLeftCorner <- circleFun(c(xmin,ymax),2.27,npoints = 50)
  TopRightCorner <- circleFun(c(xmax,ymax),2.27,npoints = 50)
  BottomLeftCorner <- circleFun(c(xmin,ymin),2.27,npoints = 50)
  BottomRightCorner <- circleFun(c(xmax,ymin),2.27,npoints = 50)
  
  plot <- plot+
    geom_path(data=TopLeftCorner %>% filter(x > 0, y < 80) , aes(x=x,y=y), colour = line_color)+
    geom_path(data=BottomLeftCorner %>% filter(x > 0, y > 0) , aes(x=x,y=y), colour = line_color)+
    geom_path(data=TopRightCorner %>% filter(x < 120, y < 80) , aes(x=x,y=y), colour = line_color) +
    geom_path(data=BottomRightCorner %>% filter(x < 120, y > 0) , aes(x=x,y=y), colour = line_color)
  
  
  
  
  return(plot)
}

# %%
pitch()
# Out:
# plot without title

# %%
install.packages("gridExtra")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
install.packages("ggplot2")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library(gridExtra)
library("ggplot2")
library(cowplot)
plot_player_ratings <- function(data, player_name)({
    
    player <- data%>%filter(Name == player_name)%>%select(Position, LS:GK)
    # Transform from column to observation
    player <- suppressWarnings(as.data.frame(t(player)) %>% 
      rownames_to_column("Pos") %>% 
      filter(Pos != "Position")%>%
      mutate(V1 = as.numeric(str_sub(V1, end = 2)),
             Pos = as.character(Pos)))

    # Create pitch & positions
    pos <- data.frame(
      Pos = as.character(c("GK","LB","LCB","CB", "RCB","RB",
                          "LWB", "LDM", "CDM", "RDM", "RWB",
                          "LM", "LCM", "CM", "RCM", "RM",
                          "LAM", "CAM", "RAM",
                          "LW","LF","CF","RF","RW",
                          "LS","ST","RS")), 
      x = c(7, rep(20,5), rep(38, 5), rep(55, 5), rep(72, 3), rep(90,5), rep(110,3)),
      y = c(40,rep(c(10, 25, 40,55,70), 3), c(20, 40, 60),c(10, 25, 40, 55,70), c(20, 40, 60)))%>%suppressWarnings()%>%suppressMessages()
    
    # Join player data & pitch
    player <- left_join(player, pos, by = 'Pos')%>%suppressWarnings()%>%suppressMessages()

    # Remove an unnecessary observation
    player <- na.omit(player)%>%suppressWarnings()%>%suppressMessages()
    
    
    p <- pitch(pitch_theme = "blue")+coord_flip()+
        geom_point(player, mapping = aes(x,y, fill = if_else(V1 < 50, "orangered", 
                                        if_else(V1 <60, "orange",
                                                if_else(V1 < 70, "goldenrod1", 
                                                        if_else(V1 <80, "palegreen4",
                                                                if_else(V1 < 90, "forestgreen",
                                                                        if_else(V1 == 0,
                                                                                "orangered","darkgreen"))))))), shape = 21, size = 25, show.legend = FALSE)+
    geom_text(player, mapping = aes(x,y, label = Pos), vjust= -0.5, color = "white", size = 4.5, fontface = "bold")+
    geom_text(player, mapping = aes(x,y, label = V1), vjust = 1.5, fontface = "bold", color = "white")+
    scale_fill_identity()+
    labs(title = paste0(player_name,"'s Overall Ratings on the Pitch"))+
    theme(plot.title = element_text(hjust = 0.5,vjust = -1, size = 30, color = "white", face = "bold"))
    return(p)
    
})
    

options(repr.plot.width = 20, repr.plot.height = 16)    
grid.arrange(
    ggdraw() +
      draw_plot(plot_player_ratings(df, "L. Messi")) +
      draw_image(df%>%filter(Name == "L. Messi")%>%pull(Player.Photo)%>%as.character, scale=0.15, y=0.3, x=-0.34)+
      draw_image(df%>%filter(Name == "L. Messi")%>%pull(Club.Logo)%>%as.character, scale=0.15, y=0.3, x=0.34),
    ggdraw() +
      draw_plot(plot_player_ratings(df, "Cristiano Ronaldo")) +
      draw_image(df%>%filter(Name == "Cristiano Ronaldo")%>%pull(Player.Photo)%>%as.character, scale=0.15, y=0.3, x=-0.34)+
      draw_image(df%>%filter(Name == "Cristiano Ronaldo")%>%pull(Club.Logo)%>%as.character, scale=0.15, y=0.3, x=0.34),
    ncol = 2
    )
# Out:
# Warning message:
# “Package `magick` is required to draw images. Image not drawn.”Warning message:
# “Package `magick` is required to draw images. Image not drawn.”Warning message:
# “Package `magick` is required to draw images. Image not drawn.”Warning message:
# “Package `magick` is required to draw images. Image not drawn.”
# plot without title

# %%
players <- df2 %>% 
  filter(Name %in% c("Cristiano Ronaldo", "L. Messi")) %>% 
# Unite Name & Club variables
  mutate(Name = paste0(Name, ", ", Club)) %>%
# Selection abilities of the players
  select(Name,Crossing:Sliding.Tackle, -Mentality, -Power, -Defending, -Skill, -Movement ) %>% 
# Correction of the punctuation
  rename_all(funs(gsub("[[:punct:]]", " ", .))) %>% 
# Tranform from Variable to Observation
  gather(Skill, Exp, Crossing:`Sliding Tackle`, -Name)


options(repr.plot.width = 15, repr.plot.height = 8)

# Becerilere göre futbolcuların ayrı ayrı görselleştirilmesi
ggplot(players, aes(Skill, Exp, fill = Name))+
  geom_col(show.legend = FALSE)+
  coord_flip()+
  facet_wrap(Name~.)+
  scale_fill_manual(values = c("black", "navy"))+
  theme_minimal()+
  theme(
      strip.text = element_text(size = 20),
      axis.title = element_text(size = 16),
      axis.text = element_text(size = 12)
  )
# Out:
# plot without title

# %%
options(repr.plot.width = 15, repr.plot.height = 8)

# Becerilere göre futbolcuların birlikte görselleştirilmesi
ggplot(players, aes(Skill, Exp, fill = Name))+
  geom_col(position = "fill")+
  coord_flip()+
  scale_fill_manual(values = c("black", "navy"))+
  theme_minimal()+
  theme(
      strip.text = element_text(size = 20),
      axis.title = element_text(size = 16),
      axis.text = element_text(size = 12),
      legend.text = element_text(size = 16),
      plot.caption = element_text(size= 10)
  )+
  geom_hline(yintercept = 0.5, color = "white", size = 1, linetype = 2)+
  theme(legend.position = "top", axis.text.x=element_blank())+
  labs(caption = "@EA Sports - FIFA 21",
       fill = NULL,x = NULL, y = NULL)
# Out:
# plot without title

# %%
install.packages("tidyverse")
# Out:
# also installing the dependencies ‘fs’, ‘rappdirs’, ‘progress’, ‘processx’, ‘evaluate’, ‘xfun’, ‘gargle’, ‘ids’, ‘vroom’, ‘tzdb’, ‘callr’, ‘knitr’, ‘broom’, ‘crayon’, ‘dbplyr’, ‘forcats’, ‘googledrive’, ‘googlesheets4’, ‘haven’, ‘hms’, ‘httr’, ‘jsonlite’, ‘lubridate’, ‘modelr’, ‘purrr’, ‘readr’, ‘reprex’, ‘rstudioapi’, ‘rvest’, ‘xml2’

# %%
install.packages('TIMP')
# Out:
# Warning message:
# “dependency ‘deSolve’ is not available”also installing the dependencies ‘dotCall64’, ‘spam’, ‘caTools’, ‘fields’, ‘nnls’, ‘minpack.lm’, ‘gclus’, ‘gplots’

# %%
## Getting specs from all players
specs = FullData[,c(22:30,36:67)]
specs = data.frame(specs)

## Specs normalization
specsNorm = preProcess(specs,method = "scale")
specs = predict(specsNorm, specs)
## Adding ID and Overall to Specs
id_overall = FullData[,c(1,20)]
specs = cbind(specs,id_overall)

##Getting prefered_positions and ID
positions = complemento[,c(53,64)]   
positions = data.frame(positions)

## Cleaning Preferred Positions

prefered_positions = positions[,'Preferred.Positions']
split = strsplit(prefered_positions, split=" ")
positionVector = 0
length = length(split)
for (position in 1:length) {
    positionVector[position] <- unlist(split[[position]][1]) 
  }
positions[,'Preferred.Positions'] = positionVector

#Joining data
selected_data = join(specs, positions, by = NULL, type = "full", match = "first") 
selected_data = selected_data[complete.cases(selected_data),]

#Attack or Defense
position = selected_data[,'Preferred.Positions']
attack = c('ST','LW','RW','RM','CM','LM','CAM','CF')
defense = c('CDM','CB','LB','RB','RWB','LWB','GK')
#Replacing
position <- lapply(position, function(x) replace(x,x %in% attack, 1))
position <- lapply(position, function(x) replace(x,x %in% defense, 0))

positionVector = 0
for (i in 1:length(position)){
    positionVector[i] = position[[i]]
}

positionVector = as.numeric(positionVector)

#joining 
selected_data = cbind(selected_data,positionVector)

selected_data <- subset( selected_data, select = -ID )
selected_data[,'Preferred.Positions'] = as.factor(selected_data[,'Preferred.Positions'])

kable(head(selected_data))
# Out:
# Error in preProcess(specs, method = "scale"): could not find function "preProcess"
# Traceback:
